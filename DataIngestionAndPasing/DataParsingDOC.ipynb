# %% [markdown]
# ### Word Doc processing

# %%
from docx import Document as DocxDocument
import os

# %%
from langchain_community.document_loaders import Docx2TextLoader, UnstructuredWordDocumentLoader
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from langchain_community.document_loaders import Docx2TextLoader, UnstructuredWordDocumentLoader
#
# ImportError: cannot import name 'Docx2TextLoader' from 'langchain_community.document_loaders' (c:\Users\Shradda\anaconda3\Lib\site-packages\langchain_community\document_loaders\__init__.py)
