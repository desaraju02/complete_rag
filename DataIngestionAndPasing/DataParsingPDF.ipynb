# %%
import os
from typing import List, Dict, Any
import pandas as pd

# %% [markdown]
# ### Loading PDF Files

# %%
from langchain_community.document_loaders import  PyPDFLoader, PyMuPDFLoader, UnstructuredPDFLoader

# %%
print("This is for ingesting PDF documents using different loaders.")
try:
    pypdf_loader = PyPDFLoader("data/pdf/apjspeech.pdf")
    pdf_docs = pypdf_loader.load()
    print(f"PyPDFLoader loaded {len(pdf_docs)} document(s).")
    print(pdf_docs)  # Print the first 200 characters of the first document
except Exception as e:
    print(f"Error loading PDF with PyPDFLoader: {e}")
# Out:
# This is for ingesting PDF documents using different loaders.
# PyPDFLoader loaded 7 document(s).
# ...

# %%
# Method 2 - PyMuPDFLoader
try:
    pymupdf_loader = PyMuPDFLoader("data/pdf/apjspeech.pdf")
    pdf_docs_mupdf = pymupdf_loader.load()
    print(f"PyMuPDFLoader loaded {len(pdf_docs_mupdf)} document(s).")
    print(pdf_docs_mupdf)  # Print the first 200 characters of the first document   
except Exception as e:
    print(f"Error loading PDF with PyMuPDFLoader: {e}")
# Out:
# PyMuPDFLoader loaded 7 document(s).
# ...

# %%
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from unstructured import documents
# class SmartPDFProcessor:
#     """ Advanced PDF processing with error handling """
#     def __init__(self, chunk_size: int = 1000, chunk_overlap: int = 200):
#         self.chunk_size = chunk_size
#         self.chunk_overlap = chunk_overlap
#         self.text_splitter = RecursiveCharacterTextSplitter(chunk_size=self.chunk_size, chunk_overlap=self.chunk_overlap, separators=["\n\n", "\n", " ", ""])
#     def process_pdf(self, file_path: str) -> List[Document]:
#         """ Process PDF with Smart Chunking and Metadata Enrichment """
#         try:
#             loader = PyPDFLoader(file_path)
#             pages = loader.load()
#             print(f"Loaded {len(pages)} page(s) from {file_path}.")

#             " Process each page"
#             processed_chunks = []
#             for page_num, page in enumerate(pages):
#                 "Clean text"
#                 cleaned_text = self.clean_text(page.page_content)
#                 "Skip empty pages"
#                 if (len(cleaned_text.strip()) < 50):
#                     print(f"Skipping empty page {page_num + 1}.")
#                     continue
#             # Add metadata
#             chunks = self.text_splitter.create_documents(
#                 [cleaned_text], 
#                 metadatas=[{"source": f"{file_path} - page {page_num + 1}"}]
#             )
#         except Exception as e:
#             print(f"Error processing PDF: {e}")
#             return []
